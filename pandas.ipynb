# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["kanav","ashna","moksh"],
    "age":[18,14,18],
    "hobby":["cricket","singing","sleeping"]
}

# %%
data=pd.DataFrame(dict1)

# %%
data
# Out:
#     name  age     hobby
# 0  kanav   18   cricket
# 1  ashna   14   singing
# 2  moksh   18  sleeping

# %%
data.head()
# Out:
#     name  age     hobby
# 0  kanav   18   cricket
# 1  ashna   14   singing
# 2  moksh   18  sleeping

# %%
data.tail(1)
# Out:
#     name  age     hobby
# 2  moksh   18  sleeping

# %%
data.describe()
# Out:
#              age
# count   3.000000
# mean   16.666667
# std     2.309401
# min    14.000000
# 25%    16.000000
# 50%    18.000000
# 75%    18.000000
# max    18.000000

# %%
data.to_csv('person.csv')

# %%
x=pd.read_csv('person.csv')

# %%
x
# Out:
#    Unnamed: 0   name  age     hobby
# 0           0  kanav   18   cricket
# 1           1  ashna   14   singing
# 2           2  moksh   18  sleeping

# %%
x['age']
# Out:
# 0    18
# 1    14
# 2    18
# Name: age, dtype: int64

# %%
x.index=['first','second','third']

# %%
x
# Out:
#         Unnamed: 0   name  age     hobby
# first            0  kanav   18   cricket
# second           1  ashna   14   singing
# third            2  moksh   18  sleeping

# %%
ser=pd.Series(np.random.rand(23))

# %%
ser
# Out:
# 0     0.861997
# 1     0.288299
# 2     0.284522
# 3     0.285790
# 4     0.240075
# 5     0.119060
# 6     0.039346
# 7     0.142997
# 8     0.982039
# 9     0.955858
# 10    0.257345
# 11    0.143274
# 12    0.937352
# 13    0.867550
# 14    0.647187
# 15    0.930359
# 16    0.211812
# 17    0.235267
# 18    0.205939
# 19    0.486593
# 20    0.318980
# 21    0.866997
# 22    0.824754
# dtype: float64

# %%
newdata=pd.DataFrame(np.random.rand(45,5))

# %%
newdata
# Out:
#            0         1         2         3         4
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925  0.486893  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703  0.092030  0.484072  0.553153  0.056897
# 5   0.159715  0.852080  0.821361  0.284793  0.916859
# 6   0.067496  0.586100  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884  0.890580  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 12  0.873640  0.711396  0.002291  0.407651  0.042966
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 14  0.565746  0.391658  0.085734  0.512756  0.693110
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# ...

# %%
newdata.describe()
# Out:
#                0          1          2          3          4
# count  45.000000  45.000000  45.000000  45.000000  45.000000
# mean    0.514597   0.588695   0.490453   0.528592   0.446519
# std     0.271440   0.315072   0.296740   0.291365   0.341473
# min     0.044969   0.032441   0.002291   0.048628   0.018045
# 25%     0.238048   0.347649   0.206073   0.284793   0.143207
# 50%     0.602703   0.639761   0.502739   0.527329   0.384788
# 75%     0.698260   0.890580   0.808740   0.760907   0.748582
# max     0.946456   0.994673   0.990939   0.997482   0.987676

# %%
newdata.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdata[1][2]="kanav"

# %%
newdata
# Out:
#            0         1         2         3         4
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925     kanav  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703   0.09203  0.484072  0.553153  0.056897
# 5   0.159715   0.85208  0.821361  0.284793  0.916859
# 6   0.067496    0.5861  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884   0.89058  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 12  0.873640  0.711396  0.002291  0.407651  0.042966
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 14  0.565746  0.391658  0.085734  0.512756  0.693110
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# ...

# %%
newdata.to_numpy()
# Out:
# array([[0.6998511385554222, 0.902919441662445, 0.20607282067017352,
#         0.5548982693863784, 0.1510987024014112],
#        [0.6846783107635002, 0.5008076745217478, 0.5339848519167673,
#         0.4493842997497358, 0.7376924275817044],
#        [0.21992529629742452, 'kanav', 0.821266189257077,
#         0.6564407728304475, 0.14320684524513394],
#        [0.2686789364833271, 0.18452722002562372, 0.23456589901633862,
#         0.5724995162965943, 0.08135369133515458],
#        [0.6027031421283714, 0.09202994550731547, 0.48407200423759367,
#         0.5531526361165454, 0.05689689861552727],
#        [0.1597152304131243, 0.8520796527577994, 0.8213607477546965,
#         0.28479255409864257, 0.916858788987287],
#        [0.06749600931555699, 0.5861002134711146, 0.557994098450656,
#         0.4343721613922783, 0.15008446226327687],
#        [0.6539937661594435, 0.9299043281493721, 0.9317830575366577,
#         0.39305477936967514, 0.2079369884445076],
# ...

# %%
newdata.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdata.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.699851  0.684678  0.219925  0.268679  0.602703  0.159715  0.067496
# 1  0.902919  0.500808     kanav  0.184527   0.09203   0.85208    0.5861
# 2  0.206073  0.533985  0.821266  0.234566  0.484072  0.821361  0.557994
# 3  0.554898  0.449384  0.656441    0.5725  0.553153  0.284793  0.434372
# 4  0.151099  0.737692  0.143207  0.081354  0.056897  0.916859  0.150084
#
#          7         8         9   ...        35        36        37        38  \
# 0  0.653994  0.224971  0.065126  ...  0.696356  0.131567  0.648021  0.717238
# 1  0.929904  0.430545  0.973478  ...  0.060102  0.199459  0.560635  0.919358
# 2  0.931783  0.843217  0.131529  ...  0.403648  0.754362  0.646443  0.990939
# 3  0.393055  0.796591  0.718802  ...  0.171275  0.657594  0.368406  0.248833
# 4  0.207937  0.935713  0.744131  ...  0.982808  0.149679  0.176753  0.947207
#
#          39        40        41        42        43        44
# ...

# %%
newdata.sort_index(axis=0)
# Out:
#            0         1         2         3         4
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925     kanav  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703   0.09203  0.484072  0.553153  0.056897
# 5   0.159715   0.85208  0.821361  0.284793  0.916859
# 6   0.067496    0.5861  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884   0.89058  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 12  0.873640  0.711396  0.002291  0.407651  0.042966
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 14  0.565746  0.391658  0.085734  0.512756  0.693110
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# ...

# %%
newdata.sort_index(axis=1,ascending=False)
# Out:
#            4         3         2         1         0
# 0   0.151099  0.554898  0.206073  0.902919  0.699851
# 1   0.737692  0.449384  0.533985  0.500808  0.684678
# 2   0.143207  0.656441  0.821266     kanav  0.219925
# 3   0.081354  0.572500  0.234566  0.184527  0.268679
# 4   0.056897  0.553153  0.484072   0.09203  0.602703
# 5   0.916859  0.284793  0.821361   0.85208  0.159715
# 6   0.150084  0.434372  0.557994    0.5861  0.067496
# 7   0.207937  0.393055  0.931783  0.929904  0.653994
# 8   0.935713  0.796591  0.843217  0.430545  0.224971
# 9   0.744131  0.718802  0.131529  0.973478  0.065126
# 10  0.094700  0.440771  0.389648   0.89058  0.146884
# 11  0.224748  0.468704  0.873119  0.347649  0.946456
# 12  0.042966  0.407651  0.002291  0.711396  0.873640
# 13  0.779095  0.965866  0.502739  0.522614  0.710629
# 14  0.693110  0.512756  0.085734  0.391658  0.565746
# 15  0.518661  0.760907  0.817357  0.325942  0.238048
# 16  0.923682  0.152021  0.861570  0.504297  0.209784
# ...

# %%
newdata[0]
# Out:
# 0     0.699851
# 1     0.684678
# 2     0.219925
# 3     0.268679
# 4     0.602703
# 5     0.159715
# 6     0.067496
# 7     0.653994
# 8     0.224971
# 9     0.065126
# 10    0.146884
# 11    0.946456
# 12    0.873640
# 13    0.710629
# 14    0.565746
# 15    0.238048
# 16    0.209784
# 17    0.421532
# 18    0.044969
# 19    0.705640
# 20    0.868214
# 21    0.698260
# 22    0.462878
# 23    0.654036
# 24    0.065193
# 25    0.662451
# 26    0.790025
# 27    0.608702
# 28    0.338291
# 29    0.592189
# 30    0.438939
# 31    0.849944
# 32    0.694666
# 33    0.945329
# 34    0.667737
# 35    0.696356
# 36    0.131567
# 37    0.648021
# 38    0.717238
# 39    0.538199
# 40    0.695765
# 41    0.877890
# 42    0.561140
# 43    0.191855
# 44    0.251519
# Name: 0, dtype: float64

# %%
type(newdata[0])
# Out:
# pandas.core.series.Series

# %%
newdata.columns=list("ABCDE")

# %%
newdata
# Out:
#            A         B         C         D         E
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925     kanav  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703   0.09203  0.484072  0.553153  0.056897
# 5   0.159715   0.85208  0.821361  0.284793  0.916859
# 6   0.067496    0.5861  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884   0.89058  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 12  0.873640  0.711396  0.002291  0.407651  0.042966
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 14  0.565746  0.391658  0.085734  0.512756  0.693110
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# ...

# %%
newdata.loc[[1,3],:]
# Out:
#           A         B         C         D         E
# 1  0.684678  0.500808  0.533985  0.449384  0.737692
# 3  0.268679  0.184527  0.234566  0.572500  0.081354

# %%
newdata.loc[(newdata['A']<0.4)|(newdata['C']>0.2)]
# Out:
#            A         B         C         D         E
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925     kanav  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703   0.09203  0.484072  0.553153  0.056897
# 5   0.159715   0.85208  0.821361  0.284793  0.916859
# 6   0.067496    0.5861  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884   0.89058  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# 17  0.421532  0.146324  0.808740  0.952656  0.896506
# 18  0.044969  0.994673  0.272777  0.050108  0.088981
# ...

# %%
newdata.iloc[0,3]
# Out:
# 0.5548982693863784

# %%
newdata.drop(['A'],axis=1)
# Out:
#            B         C         D         E
# 0   0.902919  0.206073  0.554898  0.151099
# 1   0.500808  0.533985  0.449384  0.737692
# 2      kanav  0.821266  0.656441  0.143207
# 3   0.184527  0.234566  0.572500  0.081354
# 4    0.09203  0.484072  0.553153  0.056897
# 5    0.85208  0.821361  0.284793  0.916859
# 6     0.5861  0.557994  0.434372  0.150084
# 7   0.929904  0.931783  0.393055  0.207937
# 8   0.430545  0.843217  0.796591  0.935713
# 9   0.973478  0.131529  0.718802  0.744131
# 10   0.89058  0.389648  0.440771  0.094700
# 11  0.347649  0.873119  0.468704  0.224748
# 12  0.711396  0.002291  0.407651  0.042966
# 13  0.522614  0.502739  0.965866  0.779095
# 14  0.391658  0.085734  0.512756  0.693110
# 15  0.325942  0.817357  0.760907  0.518661
# 16  0.504297  0.861570  0.152021  0.923682
# 17  0.146324  0.808740  0.952656  0.896506
# 18  0.994673  0.272777  0.050108  0.088981
# 19  0.389937  0.164520  0.870851  0.307066
# 20  0.980651  0.452114  0.094781  0.174555
# ...

# %%
newdata.reset_index(drop=True)
# Out:
#            A         B         C         D         E
# 0   0.699851  0.902919  0.206073  0.554898  0.151099
# 1   0.684678  0.500808  0.533985  0.449384  0.737692
# 2   0.219925     kanav  0.821266  0.656441  0.143207
# 3   0.268679  0.184527  0.234566  0.572500  0.081354
# 4   0.602703   0.09203  0.484072  0.553153  0.056897
# 5   0.159715   0.85208  0.821361  0.284793  0.916859
# 6   0.067496    0.5861  0.557994  0.434372  0.150084
# 7   0.653994  0.929904  0.931783  0.393055  0.207937
# 8   0.224971  0.430545  0.843217  0.796591  0.935713
# 9   0.065126  0.973478  0.131529  0.718802  0.744131
# 10  0.146884   0.89058  0.389648  0.440771  0.094700
# 11  0.946456  0.347649  0.873119  0.468704  0.224748
# 12  0.873640  0.711396  0.002291  0.407651  0.042966
# 13  0.710629  0.522614  0.502739  0.965866  0.779095
# 14  0.565746  0.391658  0.085734  0.512756  0.693110
# 15  0.238048  0.325942  0.817357  0.760907  0.518661
# 16  0.209784  0.504297  0.861570  0.152021  0.923682
# ...

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       45 non-null     float64
#  1   B       45 non-null     object
#  2   C       45 non-null     float64
#  3   D       45 non-null     float64
#  4   E       45 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.9+ KB

# %%
exc=pd.read_excel('student.xlrd')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 exc=pd.read_excel('student.xlrd')
#
# File ~\anaconda5\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...
